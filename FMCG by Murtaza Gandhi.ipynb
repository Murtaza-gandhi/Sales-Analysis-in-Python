# %%
import pandas as pd
import numpy as np 
import datetime as dt

# %%
df = pd.DataFrame(pd.read_csv("Raw Sales Data.csv"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month         224 non-null    object
#  1   Channel       224 non-null    object
#  2   Sub-Channels  224 non-null    object
#  3   Product Name  224 non-null    object
#  4   Category      224 non-null    object
#  5   Qty           224 non-null    object
#  6   Sales         224 non-null    object
# dtypes: object(7)
# memory usage: 12.4+ KB

# %%
pd.DataFrame(df.groupby("Category")["Qty"].sum())
# Out:
#                          Qty
# Category
# Functional nutrition   42354
# Gourmet Nutrition      89279
# Juices                178148

# %%
df
# Out:
#          Month      Channel Sub-Channels                  Product Name  \
# 0   2020-12-01  Marketplace       AMAZON         ALOE + AMLA JUICE 1 L
# 1   2020-12-01  Marketplace       AMAZON     ALOE + GARCINIA JUICE 1 L
# 2   2020-12-01  Marketplace       AMAZON           ALOE VERA JUICE 1 L
# 3   2020-12-01  Marketplace       AMAZON     ALOE VERA SKIN GEL 500 GM
# 4   2020-12-01  Marketplace       AMAZON                NEEM JUICE 1 L
# ..         ...          ...          ...                           ...
# 219 2021-03-01  Marketplace   Big Basket      ORGANIC GULKAND 300grams
# 220 2021-03-01  Marketplace     Flipkart     ALOE + GARCINIA JUICE 1 L
# 221 2021-03-01  Marketplace     Flipkart                AMLA JUICE 1 L
# 222 2021-03-01  Marketplace     Flipkart            GET SLIM JUICE 1 L
# 223 2021-03-01  Marketplace        GOQII  RAW HONEY ( MADHU) 500 GRAMS
#
#               Category   Qty    Sales Month-Year
# 0               Juices  1116   428700     Dec-20
# ...

# %%
df["Qty"] = df["Qty"].str.replace(",","").astype(int)
df["Sales"] = df["Sales"].str.replace(",","").astype(int)
df['Month'] = pd.to_datetime(df["Month"])

# %% [markdown]
# # Requariment 1
#
# # Monthwise number of quantities sold

# %%
df
# Out:
#          Month      Channel Sub-Channels                  Product Name  \
# 0   2020-12-01  Marketplace       AMAZON         ALOE + AMLA JUICE 1 L
# 1   2020-12-01  Marketplace       AMAZON     ALOE + GARCINIA JUICE 1 L
# 2   2020-12-01  Marketplace       AMAZON           ALOE VERA JUICE 1 L
# 3   2020-12-01  Marketplace       AMAZON     ALOE VERA SKIN GEL 500 GM
# 4   2020-12-01  Marketplace       AMAZON                NEEM JUICE 1 L
# ..         ...          ...          ...                           ...
# 219 2021-03-01  Marketplace   Big Basket      ORGANIC GULKAND 300grams
# 220 2021-03-01  Marketplace     Flipkart     ALOE + GARCINIA JUICE 1 L
# 221 2021-03-01  Marketplace     Flipkart                AMLA JUICE 1 L
# 222 2021-03-01  Marketplace     Flipkart            GET SLIM JUICE 1 L
# 223 2021-03-01  Marketplace        GOQII  RAW HONEY ( MADHU) 500 GRAMS
#
#               Category   Qty    Sales
# 0               Juices  1116   428700
# ...

# %%
df['Month-Year']= df['Month'].dt.strftime("%b-%y")

# %%
monthqty = pd.DataFrame(df.groupby("Month-Year")['Qty'].sum()).reset_index()
monthqty
# Out:
#   Month-Year    Qty
# 0     Dec-20  85427
# 1     Feb-21  76393
# 2     Jan-21  67732
# 3     Mar-21  80229

# %% [markdown]
# # Requirement 2
#
# # Category wise Qty sold

# %%
Category = pd.DataFrame(df.groupby("Category")["Qty"].sum()).reset_index()
Category
# Out:
#                Category     Qty
# 0  Functional nutrition   42354
# 1     Gourmet Nutrition   89279
# 2                Juices  178148

# %% [markdown]
# # Requirement 3
#
# # Sub-channel wise total sales

# %%
Sub_channel = pd.DataFrame(df.groupby("Sub-Channels")["Sales"].sum()).reset_index()
Sub_channel
# Out:
#          Sub-Channels     Sales
# 0              AMAZON  35606804
# 1          Big Basket   1207522
# 2                 D2C  28047538
# 3            Flipkart   3770415
# 4               GOQII    582600
# 5   Offline - Central    375332
# 6      Offline - East    811146
# 7        Offline - MT   6257948
# 8     Offline - South   3446395
# 9      Offline - West   6441427
# 10     Offline -North   1206564

# %% [markdown]
# # Requirement 4
#
# # Highest sale in which month

# %%
monthly_sales = pd.DataFrame(df.groupby('Month-Year')["Sales"].sum()).reset_index()

monthly_sales.sort_values("Sales",ascending=False).head(1)
# Out:
#   Month-Year     Sales
# 3     Mar-21  25127827

# %% [markdown]
# # Requirement 5
#
# # Highest selling product (based on sales)

# %%
prdinfo = df.copy()
prdinfo["Product Name"]= prdinfo["Product Name"].str.replace('\d+', '---').str.split("---").str[0]


product_sales = pd.DataFrame(prdinfo.groupby("Product Name")["Sales"].sum()).reset_index()
product_sales.sort_values("Sales",ascending=False).head(1)
# Out:
# C:\Users\Murtaza G\AppData\Local\Temp\ipykernel_22956\1813059370.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   prdinfo["Product Name"]= prdinfo["Product Name"].str.replace('\d+', '---').str.split("---").str[0]
#              Product Name     Sales
# 1  ALOE + GARCINIA JUICE   12249252

# %% [markdown]
# # Requirement 6
#
# # List of different products company is offering

# %%
prd_comp = prdinfo.drop("Sales",axis=1)
prd_comp.sort_values("Product Name",ascending=False)
# Out:
#          Month      Channel  Sub-Channels        Product Name Category   Qty  \
# 123 2021-02-01  Marketplace        AMAZON  WHEAT GRASS JUICE    Juices  2082
# 214 2021-03-01  Marketplace        AMAZON  WHEAT GRASS JUICE    Juices  2283
# 76  2021-01-01  Marketplace        AMAZON  WHEAT GRASS JUICE    Juices  1823
# 180 2021-03-01      Offline  Offline - MT  WHEAT GRASS JUICE    Juices   552
# 173 2021-03-01          D2C           D2C  WHEAT GRASS JUICE    Juices   684
# ..         ...          ...           ...                 ...      ...   ...
# 56  2021-01-01  Marketplace        AMAZON  ALOE + AMLA JUICE    Juices  1224
# 215 2021-03-01  Marketplace    Big Basket  ALOE + AMLA JUICE    Juices   615
# 108 2021-02-01  Marketplace        AMAZON  ALOE + AMLA JUICE    Juices  1049
# 199 2021-03-01  Marketplace        AMAZON  ALOE + AMLA JUICE    Juices  1059
# 0   2020-12-01  Marketplace        AMAZON  ALOE + AMLA JUICE    Juices  1116
#
#     Month-Year
# 123     Feb-21
# ...

# %%
prd_comp.describe()

# %%
prd_comp['Product Name'].nunique()

# %% [markdown]
# # Requirement 7
# # save all the data in the excle file

# %%
writer = pd.ExcelWriter("C:\\Users\\Murtaza G\\Desktop\\Murtaza (python 1st)\\Data Sets\\FMCG\\FMCG Excel.xlsx")

monthqty.to_excel(writer,sheet_name = "Monthaly Sales",index=False)

Category.to_excel(writer,sheet_name = "Catagory Wise Qty Sold",index=False)

Sub_channel.to_excel(writer,sheet_name = "Sub-Channel wise sales",index=False)

monthly_sales.to_excel(writer,sheet_name = "Monthly Sales",index=False)

product_sales.to_excel(writer,sheet_name = "Product wise Sales",index=False)

prd_comp.to_excel(writer,sheet_name = "Company Names",index=False)


writer.save()
